# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

# %%
sentiment_analysis_df = pd.read_csv("/Users/hienanh/Documents/GitHub/BoE_ARP_model/main_df_output/sentiment_analysis_df.csv")
sentiment_analysis_df_with_price = pd.read_csv('/Users/hienanh/Documents/GitHub/BoE_ARP_model/main_df_output/sentiment_analysis_df_with_price.csv')

# %%
from pygam.datasets import wage
from pygam import LinearGAM, s, f, PoissonGAM, GammaGAM

from sklearn.preprocessing import OneHotEncoder

import plotly.express as px

# %%
df = sentiment_analysis_df_with_price.copy()

column_day = df.columns[8:]
column_day
# Out:
# Index(['D-1', 'D+1', 'D-2', 'D+2', 'D-3', 'D+3', 'D-5', 'D+5', 'D-10', 'D+10',
#        'D-15', 'D+15'],
#       dtype='object')

# %%
# label encoder
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df_run = pd.DataFrame()
df_run['group'] = labelencoder.fit_transform(df['Group'])
df_run['sentiment'] = df['WA_sentiment']
df_run = df_run.join(df[column_day])
df_run
# Out:
#       group  sentiment       D-1       D+1       D-2       D+2       D-3  \
# 0         6  -0.020513 -0.031030  0.013897 -0.020130  0.015106 -0.003612
# 1         6   0.001994 -0.118567 -0.054693 -0.110454 -0.025868 -0.094983
# 2         6  -0.012026 -0.256077 -0.076056 -0.247881 -0.053521 -0.251686
# 3         6  -0.000319 -0.256077 -0.076056 -0.247881 -0.053521 -0.251686
# 4         6  -0.031913  0.100000  0.015734  0.095785  0.012238  0.080264
# ...     ...        ...       ...       ...       ...       ...       ...
# 1809      7   0.002050  0.063332 -0.018274  0.069258 -0.019425  0.073609
# 1810      7  -0.009964  0.034267 -0.013371  0.041432 -0.016994  0.039294
# 1811      7  -0.001660 -0.016541 -0.011460 -0.027909 -0.011521 -0.015945
# 1812      7  -0.005704  0.001828 -0.002943  0.008669  0.000706  0.007592
# 1813      7  -0.007471  0.022143  0.001295  0.027895 -0.006888  0.018711
#
#            D+3       D-5       D+5      D-10      D+10      D-15      D+15
# 0    -0.000604 -0.011350 -0.003021 -0.029326 -0.060423 -0.030463 -0.045317
# 1    -0.005913 -0.125969  0.011086 -0.031496  0.008130 -0.117417 -0.028825
# 2    -0.061972 -0.234914 -0.098028 -0.276691 -0.025352 -0.275510  0.039437
# 3    -0.061972 -0.234914 -0.098028 -0.276691 -0.025352 -0.275510  0.039437
# 4     0.022727  0.062210  0.036713  0.103182  0.020979  0.179990  0.014860
# ...        ...       ...       ...       ...       ...       ...       ...
# 1809 -0.060778  0.063179 -0.080203  0.031990  0.000203  0.026255 -0.019628
# 1810 -0.032275  0.050876 -0.041101  0.061678 -0.054802  0.054013 -0.033263
# 1811 -0.015218 -0.009157 -0.027663 -0.003744  0.002403 -0.002704  0.041341
# 1812 -0.002826  0.000294  0.000530  0.001238  0.026725 -0.010427  0.036320
# 1813 -0.019191  0.027398 -0.006946  0.011793 -0.032083  0.011914 -0.057279
#
# [1814 rows x 14 columns]
